# %%
#%pip install azure-ai-ml

# %%
from azure.ai.ml import MLClient, command, dsl, Input, Output
from azure.ai.ml.entities import RecurrenceTrigger, RecurrencePattern, JobSchedule, Environment
from azure.identity import DefaultAzureCredential

# 1. Authenticate
ml_client = MLClient(
    credential=DefaultAzureCredential(),
    subscription_id="26b57ef9-1628-4837-a014-81f6424512c1",
    resource_group_name="rg-trading-bot-dev",
    workspace_name="ml-trading-workspace"
)

# 2. Define Environment
ml_env = Environment(
    name="trading-cluster-env",
    image="mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04",
    conda_file="conda.yml"
)

# 3A. Define STEP 1: The ETL Component
etl_component = command(
    code="./",  
    # THE FIX: If python succeeds, we use 'echo' to create a dummy file to signal Step 2.
    command="python etl_pipeline.py && echo 'done' > ${{outputs.signal_file}}",
    environment=ml_env,
    compute="trading-dev-machine",
    display_name="1_Data_Engineering_ETL",
    outputs={"signal_file": Output(type="uri_file")} # Declare the output
)

# 3B. Define STEP 2: The AI Component
ai_component = command(
    code="./",  
    command="python ai_agent.py", # Notice the Python script ignores the dummy input!
    environment=ml_env,
    compute="trading-dev-machine",
    display_name="2_Agentic_Thesis_Gen",
    inputs={"wait_for_signal": Input(type="uri_file")}, # Declare the dependency
    environment_variables={
        "KEY_VAULT_URL": "https://kv-mlworkspace26.vault.azure.net/"
    }
)

# 4. Construct the Dependency Graph
@dsl.pipeline(
    name="decoupled_quant_pipeline",
    description="2-Step Architecture: ETL followed by AI Generation"
)
def my_quant_pipeline():
    # Instantiate Step 1
    step_1 = etl_component()
    
    # ENFORCE THE DEPENDENCY: Pass Step 1's dummy output directly into Step 2
    step_2 = ai_component(wait_for_signal=step_1.outputs.signal_file)

pipeline_job = my_quant_pipeline()

# 5. Schedule It
job_schedule = JobSchedule(
    name="daily_market_clustering_schedule",
    trigger=RecurrenceTrigger(
        frequency="day",
        interval=1,
        schedule=RecurrencePattern(hours=21, minutes=30)
    ),
    create_job=pipeline_job
)

ml_client.schedules.begin_create_or_update(job_schedule)
print("✅ Multi-Step MLOps Schedule created with Dummy Signal dependency!")
# Out:
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 54
#      51     # ENFORCE THE DEPENDENCY: Step 2 cannot start until Step 1 succeeds
#      52     step_2.after(step_1)
# ---> 54 pipeline_job = my_quant_pipeline()
#      56 # 5. Schedule It
#      57 job_schedule = JobSchedule(
#      58     name="daily_market_clustering_schedule",
#      59     trigger=RecurrenceTrigger(
#    (...)
#      64     create_job=pipeline_job
#      65 )
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/dsl/_pipeline_decorator.py:200, in pipeline.<locals>.pipeline_decorator.<locals>.wrapper(*args, **kwargs)
#     195     non_pipeline_params_dict = {
#     196         k: v for k, v in provided_positional_kwargs.items() if k in non_pipeline_inputs
#     197     }
#     199     # TODO: cache built pipeline component
# --> 200     pipeline_component = pipeline_builder.build(
#     201         user_provided_kwargs=provided_positional_kwargs,
#     202         non_pipeline_inputs_dict=non_pipeline_params_dict,
#     203         non_pipeline_inputs=non_pipeline_inputs,
#     204     )
#     205 finally:
#     206     # use `finally` to ensure pop operation from the stack
#     207     dsl_settings = _dsl_settings_stack.pop()
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/dsl/_pipeline_component_builder.py:191, in PipelineComponentBuilder.build(self, user_provided_kwargs, non_pipeline_inputs_dict, non_pipeline_inputs)
#     188 _definition_builder_stack.push(self)
#     190 try:
# --> 191     outputs, _locals = get_outputs_and_locals(self.func, kwargs)
#     192 finally:
#     193     _definition_builder_stack.pop()
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_utils/_func_utils.py:471, in get_outputs_and_locals(func, _all_kwargs)
#     461 def get_outputs_and_locals(func, _all_kwargs):
#     462     """Get outputs and locals from self.func. Locals will be used to update node variable names.
#     463
#     464     :param func: The function to execute.
#    (...)
#     469     :rtype: typing.Tuple[typing.Dict, typing.Dict]
#     470     """
# --> 471     return _get_persistent_locals_builder().call(func, _all_kwargs)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_utils/_func_utils.py:63, in PersistentLocalsFunctionBuilder.call(self, func, _all_kwargs)
#      60 if self.injected_param in func.__code__.co_varnames:
#      61     raise ValueError(self.make_error("conflict_argument", args=list(func.__code__.co_varnames)))
# ---> 63 return self._call(func, _all_kwargs)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_utils/_func_utils.py:109, in PersistentLocalsFunctionProfilerBuilder._call(self, func, _all_kwargs)
#     107 func_variable_profiler = self._get_func_variable_tracer(_locals, func.__code__)
#     108 with self._replace_sys_profiler(func_variable_profiler):
# --> 109     outputs = func(**_all_kwargs)
#     110 return outputs, _locals
#
# Cell In[3], line 52, in my_quant_pipeline()
#      49 step_2 = ai_component()
#      51 # ENFORCE THE DEPENDENCY: Step 2 cannot start until Step 1 succeeds
# ---> 52 step_2.after(step_1)
#
# TypeError: '_AttrDict' object is not callable
